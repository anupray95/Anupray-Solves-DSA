# %% [markdown]
# ## 70. Climbing Stairs
# <span style="
#     display:inline-flex;
#     align-items:center;
#     padding:6px 16px;
#     border-radius:999px;
#     background-color:#eefdfb;
#     color:#2cbfb3;
#     font-size:18px;
#     font-weight:500;
#     font-family: system-ui, -apple-system, BlinkMacSystemFont;
# ">
#     Easy
# </span>

# %% [markdown]
# https://leetcode.com/problems/climbing-stairs/submissions/1892443159
#
#
# Solution: https://leetcode.com/problems/climbing-stairs/submissions/1892443159

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        dp = [None]*(n+1)
        dp[0] = 1
        dp[1] = 1
        # for each step,we can go from prev or prev-1 steps
        # so add both previous result and return
        for i in range(2, n+1):
            dp[i] = dp[i-1] + dp[i-2]
        return dp[n]
